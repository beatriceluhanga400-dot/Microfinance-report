# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/REPORT01.csv")
df.head()
# Out:
#               Office    LoanOfficer                   Client  \
# 0  NACHINGWEA BRANCH  SIKA, EXCEVIA   Semeni Rajabu Chambuso
# 1  NACHINGWEA BRANCH  SIKA, EXCEVIA  Abdalah Hamisi Abdallah
# 2  NACHINGWEA BRANCH  SIKA, EXCEVIA     Ibadi Chande Ngalita
# 3  NACHINGWEA BRANCH  SIKA, EXCEVIA     Shadrack Alex Kipeto
# 4  NACHINGWEA BRANCH  SIKA, EXCEVIA    Fikiri Bakari Mandoga
#
#              Product TransactionDate     Amount PaymentType      BRANCH  \
# 0        Simama Loan       7/23/2025  2200000.0    NMB Bank  NACHINGWEA
# 1         Inuka Loan        7/8/2025   150000.0    NMB Bank  NACHINGWEA
# 2  Watumishi Private       7/30/2025   300000.0    NMB Bank  NACHINGWEA
# 3         Inuka Loan       7/29/2025   300000.0    NMB Bank  NACHINGWEA
# 4         Inuka Loan       7/29/2025   500000.0    NMB Bank  NACHINGWEA
#
#              ClientsName LoanAccount No PrincipalAmount  Interest Amount  \
# 0    Ally Omary Mbalanga     SL000009..        67695.49          2304.51
# ...

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8075 entries, 0 to 8074
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Office                1325 non-null   object
#  1   LoanOfficer           1321 non-null   object
#  2   Client                1325 non-null   object
#  3   Product               1325 non-null   object
#  4   TransactionDate       1325 non-null   object
#  5   Amount                1325 non-null   float64
#  6   PaymentType           1325 non-null   object
#  7   BRANCH                8075 non-null   object
#  8   ClientsName           8075 non-null   object
#  9   LoanAccount No        8075 non-null   object
#  10  PrincipalAmount       8075 non-null   object
#  11  Interest Amount       8075 non-null   float64
#  12  Fees                  8075 non-null   float64
#  13  Penalty               8075 non-null   int64
#  14  Others                8075 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Office                  6750
# LoanOfficer             6754
# Client                  6750
# Product                 6750
# TransactionDate         6750
# Amount                  6750
# PaymentType             6750
# BRANCH                     0
# ClientsName                0
# LoanAccount No             0
# PrincipalAmount            0
# Interest Amount            0
# Fees                       0
# Penalty                    0
# Others                     0
# Total Receipt Amount       0
# Action Date                0
# dtype: int64

# %%
cleaned_df=df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)
cleaned_df

# %%
df.to_csv("../output/cleaned_df.csv", index=False)

# %%
cleaned_df = df.dropna()
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1321 entries, 0 to 1320
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Office                1321 non-null   object
#  1   LoanOfficer           1321 non-null   object
#  2   Client                1321 non-null   object
#  3   Product               1321 non-null   object
#  4   TransactionDate       1321 non-null   object
#  5   Amount                1321 non-null   float64
#  6   PaymentType           1321 non-null   object
#  7   BRANCH                1321 non-null   object
#  8   ClientsName           1321 non-null   object
#  9   LoanAccount No        1321 non-null   object
#  10  PrincipalAmount       1321 non-null   object
#  11  Interest Amount       1321 non-null   float64
#  12  Fees                  1321 non-null   float64
#  13  Penalty               1321 non-null   int64
#  14  Others                1321 non-null   float64
# ...

# %%
cleaned_df["LoanOfficer"].value_counts().head()
# Out:
# LoanOfficer
# Mdachi, Yassin      111
# MWESE,  CAROLINE     88
# SADICK, NOAH         86
# PILIKANO,  ESHA      84
# SIKA, EXCEVIA        82
# Name: count, dtype: int64

# %%
cleaned_df["Client"].value_counts().head()
# Out:
# Client
# Fedrick Faustini Makonda    3
# Aliasa Asili Zayumba        2
# Rajabu Yusuph Sudi          2
# Saidi Mohamedi Chimela      2
# Mohamedi Saidi Matula       2
# Name: count, dtype: int64

# %%
plt.hist(cleaned_df["Amount"])
plt.title("Histogram of Loan Amount")
plt.xlabel("Loan Amount")
plt.ylabel("Frequency")
plt.savefig("../charts/histogram_amount.png",dpi=300,bbox_inches="tight")
plt.show()

# %%
plt.plot(cleaned_df["Interest Amount"])
plt.title("Interest Amount Trend")
plt.xlabel("Transaction Index")
plt.ylabel("Interest Amount")
plt.savefig("../charts/interest_amount.png",dpi=300,bbox_inches="tight")
plt.show()
